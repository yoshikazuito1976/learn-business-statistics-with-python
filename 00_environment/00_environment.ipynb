# %% [markdown]
# # 00 Environment
#
# このノートブックでは、ビジネス統計を学ぶための実行環境を確認します。
#
# この章で行うことは、次の最低限の動作確認です。
#
# - Python を実行できる
# - 簡単な計算ができる
# - 乱数を生成できる
# - matplotlib をインストールしてグラフを表示できる
#
# 目的は、環境が整っていることを確認することです。

# %% [markdown]
# ## 1. Python が動くことを確認する
#
# まずは、Python が実行できることを確認します。

# %%
print("Hello, Business Statistics")
# Out:
# Hello, Business Statistics

# %% [markdown]
# ## 2. 簡単な計算をしてみる
#
# ビジネス統計では、売上・割合・平均など、数値を扱います。
#
# ここでは、1000円の商品に10%の税金を加えた金額を計算してみます。

# %%
price = 1000
tax_rate = 0.1

total = price + price * tax_rate

print(total)
# Out:
# 1100.0

# %% [markdown]
# ## 3. 乱数を使ってみる
#
# 確率やシミュレーションでは、乱数を使います。
#
# 乱数とは、実行するたびに変わる可能性のある数のことです。

# %%
import random

number = random.random()

print(number)
# Out:
# 0.5951185651558158

# %% [markdown]
# `random.random()` は、0以上1未満の数をランダムに作ります。
#
# このセルを何度か実行してみてください。
# 毎回同じ値になるとは限りません。
#
# ## 4. matplotlib の確認
#
# ここからは、グラフ描画に必要な `matplotlib` のインストールと動作確認を行います。

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# /usr/bin/python3.12
# 3.12.12 (main, Apr 16 2026, 00:00:00) [GCC 11.5.0 20240719 (Red Hat 11.5.0-11)]

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/siwuser/.local/lib/python3.12/site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/siwuser/.local/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/siwuser/.local/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/siwuser/.local/lib/python3.12/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/siwuser/.local/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /home/siwuser/.local/lib/python3.12/site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /home/siwuser/.local/lib/python3.12/site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /home/siwuser/.local/lib/python3.12/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/siwuser/.local/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/siwuser/.local/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/siwuser/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import matplotlib.pyplot as plt

labels = ["A", "B", "C"]
values = [3, 5, 2]

plt.bar(labels, values)
plt.title("Matplotlib Check")
plt.xlabel("Category")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# ## 5. このノートブックで確認したこと
#
# このノートブックでは、次のことを確認しました。
#
# - Python を実行できる
# - 簡単な計算ができる
# - 乱数を生成できる
# - matplotlib をインストールできる
# - グラフを表示できる
#
# 次の章から、確率と試行の内容に進みます。
