# %% [markdown]
# # 00 Environment
#
# このノートブックでは、ビジネス統計を学ぶための実行環境を確認します。
#
# この章で行うことは、次の最低限の動作確認です。
#
# - Python を実行できる
# - 簡単な計算ができる
# - 乱数を生成できる
# - matplotlib をインストールしてグラフを表示できる
#
# 目的は、環境が整っていることを確認することです。

# %% [markdown]
# ## 1. Python が動くことを確認する
#
# まずは、Python が実行できることを確認します。

# %%
print("Hello, Business Statistics")
# Out:
# Hello, Business Statistics

# %% [markdown]
# ## 2. 簡単な計算をしてみる
#
# ビジネス統計では、売上・割合・平均など、数値を扱います。
#
# ここでは、1000円の商品に10%の税金を加えた金額を計算してみます。

# %%
price = 1000
tax_rate = 0.1

total = price + price * tax_rate

print(total)
# Out:
# 1100.0

# %% [markdown]
# ## 3. 乱数を使ってみる
#
# 確率やシミュレーションでは、乱数を使います。
#
# 乱数とは、実行するたびに変わる可能性のある数のことです。

# %%
import random

number = random.random()

print(number)
# Out:
# 0.6139530504872588

# %% [markdown]
# `random.random()` は、0以上1未満の数をランダムに作ります。
#
# このセルを何度か実行してみてください。
# 毎回同じ値になるとは限りません。
#
# ## 4. matplotlib の確認
#
# ここからは、グラフ描画に必要な `matplotlib` のインストールと動作確認を行います。

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# /usr/bin/python
# 3.12.12 (main, Mar 27 2026, 00:00:00) [GCC 14.3.1 20250617 (Red Hat 14.3.1-2)]

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 264.7 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 785.0 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 10.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.6/362.6 kB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 7.3 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 36.2 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 17.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 28.9 MB/s eta 0:00:0000:0100:01
# ...

# %%
import matplotlib.pyplot as plt

labels = ["A", "B", "C"]
values = [3, 5, 2]

plt.bar(labels, values)
plt.title("Matplotlib Check")
plt.xlabel("Category")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# ## 5. このノートブックで確認したこと
#
# このノートブックでは、次のことを確認しました。
#
# - Python を実行できる
# - 簡単な計算ができる
# - 乱数を生成できる
# - matplotlib をインストールできる
# - グラフを表示できる
#
# 次の章から、確率と試行の内容に進みます。
